# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/processed/clean_employees.csv")

# %%
# Box plot for salary distribution
df["salary"].hist()
plt.show()

# %%
# Box plot for salary distribution
df["salary"].hist()
plt.show()

# %%
# Bar chart for department distribution
df["department"].value_counts().plot(kind="bar")
plt.show()

# %%
# Pie chart for region distribution
df["region"].value_counts().plot(kind="pie")
plt.show()
